# %%
import pandas as pd

# %%
import os

# Directory containing your CSV files
csv_directory = '/home/sysadm/Desktop/Term project/csvfile with whom i kriging'

# List all CSV files in the directory and print their full paths
for root, _, files in os.walk(csv_directory):
    for file in files:
        if file.endswith('.csv'):
            file_path = os.path.join(root, file)
            print(file_path)
# Out:
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/2023_below_33_percentage.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/2023_below_33_percentage_kriging.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2020_sorted_dates.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/2020_below_33_percentage.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/2018_below_33_percentage_kriging_merged_mixed.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2022_sorted_dates.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2021_sorted_dates.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/2022_below_33_percentage_kriging.csv
# /home/sysadm/Desktop/Term project/csvfile with whom i kriging/2018_below_33_percentage.csv
# ...

# %%
df_2023_kriging = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/2023_below_33_percentage_kriging.csv")
df_2023_kriging
# Out:
#       latitude  longitude  2023-01-04  2023-02-04  2023-02-06  2023-03-07  \
# 0       28.414     77.171       0.339       0.665       0.715       0.609
# 1       28.414     77.181       0.349       0.662       0.664       0.623
# 2       28.414     77.192       0.363       0.662       0.664       0.637
# 3       28.414     77.202       0.368       0.706       0.649       0.634
# 4       28.414     77.213       0.373       0.664       0.662       0.639
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.375       0.538       0.794       0.424
# 1346    28.864     77.088       0.358       0.643       0.783       0.398
# 1347    28.864     77.098       0.360       0.641       0.782       0.409
# 1348    28.864     77.109       0.358       0.597       0.765       0.425
# 1349    28.874     77.088       0.386       0.542       0.777       0.407
#
#       2021-02-22  2021-02-23  2021-02-25  2021-02-27  ...  2023-08-07  \
# ...

# %%
df_2023_below_33 = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/2023_below_33_percentage.csv")
df_2023_below_33
# Out:
#       latitude  longitude  2023-01-01  2023-01-03  2023-01-04  2023-01-05  \
# 0       28.414     77.171       0.317       0.567       0.339       0.375
# 1       28.414     77.181       0.329       0.573       0.349       0.375
# 2       28.414     77.192       0.334       0.571       0.363       0.373
# 3       28.414     77.202       0.339       0.588       0.368       0.385
# 4       28.414     77.213       0.345       0.605       0.373       0.398
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.323       0.430       0.375       0.414
# 1346    28.864     77.088       0.325       0.405       0.358       0.408
# 1347    28.864     77.098       0.328       0.417       0.360       0.409
# 1348    28.864     77.109       0.343       0.455       0.358       0.409
# 1349    28.874     77.088       0.338       0.438       0.386       0.417
#
#       2023-01-06  2023-01-10  2023-01-15  2023-01-17  ...  2023-08-07  \
# ...

# %%
df = df_2023_below_33

# %%
# Assuming your DataFrame is named 'df'

# List of columns with 2021 dates to be removed
columns_to_remove = [col for col in df.columns if col.startswith('2021')]

# Drop the columns with 2021 dates
df = df.drop(columns=columns_to_remove)

# Print or use the modified DataFrame 'df' as needed
print(df)
# Out:
#       latitude  longitude  2023-01-01  2023-01-03  2023-01-04  2023-01-05  \
# 0       28.414     77.171       0.317       0.567       0.339       0.375
# 1       28.414     77.181       0.329       0.573       0.349       0.375
# 2       28.414     77.192       0.334       0.571       0.363       0.373
# 3       28.414     77.202       0.339       0.588       0.368       0.385
# 4       28.414     77.213       0.345       0.605       0.373       0.398
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.323       0.430       0.375       0.414
# 1346    28.864     77.088       0.325       0.405       0.358       0.408
# 1347    28.864     77.098       0.328       0.417       0.360       0.409
# 1348    28.864     77.109       0.343       0.455       0.358       0.409
# 1349    28.874     77.088       0.338       0.438       0.386       0.417
#
#       2023-01-06  2023-01-10  2023-01-15  2023-01-17  ...  2023-08-07  \
# ...

# %%
df.to_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/2023_below_33_percentage.csv",index = False)

# %%
df_2023_below_33_percentage = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/2023_below_33_percentage_kriging.csv")
df_2023_below_33_percentage
# Out:
#       latitude  longitude  2023-01-04  2023-02-04  2023-02-06  2023-03-07  \
# 0       28.414     77.171       0.339       0.665       0.715       0.609
# 1       28.414     77.181       0.349       0.662       0.664       0.623
# 2       28.414     77.192       0.363       0.662       0.664       0.637
# 3       28.414     77.202       0.368       0.706       0.649       0.634
# 4       28.414     77.213       0.373       0.664       0.662       0.639
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.375       0.538       0.794       0.424
# 1346    28.864     77.088       0.358       0.643       0.783       0.398
# 1347    28.864     77.098       0.360       0.641       0.782       0.409
# 1348    28.864     77.109       0.358       0.597       0.765       0.425
# 1349    28.874     77.088       0.386       0.542       0.777       0.407
#
#       2021-02-22  2021-02-23  2021-02-25  2021-02-27  ...  2023-08-07  \
# ...

# %%
df = df_2023_below_33

# %%
# Assuming your DataFrame is named 'df'

# List of columns with 2021 dates to be removed
columns_to_remove = [col for col in df.columns if col.startswith('2021')]

# Drop the columns with 2021 dates
df = df.drop(columns=columns_to_remove)

# Print or use the modified DataFrame 'df' as needed
print(df)
# Out:
#       latitude  longitude  2023-01-01  2023-01-03  2023-01-04  2023-01-05  \
# 0       28.414     77.171       0.317       0.567       0.339       0.375
# 1       28.414     77.181       0.329       0.573       0.349       0.375
# 2       28.414     77.192       0.334       0.571       0.363       0.373
# 3       28.414     77.202       0.339       0.588       0.368       0.385
# 4       28.414     77.213       0.345       0.605       0.373       0.398
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.323       0.430       0.375       0.414
# 1346    28.864     77.088       0.325       0.405       0.358       0.408
# 1347    28.864     77.098       0.328       0.417       0.360       0.409
# 1348    28.864     77.109       0.343       0.455       0.358       0.409
# 1349    28.874     77.088       0.338       0.438       0.386       0.417
#
#       2023-01-06  2023-01-10  2023-01-15  2023-01-17  ...  2023-08-07  \
# ...

# %%
df.to_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/2023_below_33_percentage.csv",index = False)

# %%
df_2023_kriging.columns
# Out:
# Index(['latitude', 'longitude', '2023-01-04', '2023-02-04', '2023-02-06',
#        '2023-03-07', '2021-02-22', '2021-02-23', '2021-02-25', '2021-02-27',
#        ...
#        '2023-08-07', '2023-08-11', '2023-08-12', '2023-08-16', '2023-08-17',
#        '2023-09-09', '2023-09-10', '2023-09-12', '2023-09-14', '2023-09-22'],
#       dtype='object', length=105)

# %%
df_2023 = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2023_sorted_dates.csv")

# %%
df_2023.head()
# Out:
#    latitude  longitude  2023-01-01  2023-01-02  2023-01-03  2023-01-04  \
# 0    28.414     77.171       0.317         NaN       0.567       0.339
# 1    28.414     77.181       0.329         NaN       0.573       0.349
# 2    28.414     77.192       0.334         NaN       0.571       0.363
# 3    28.414     77.202       0.339         NaN       0.588       0.368
# 4    28.414     77.213       0.345         NaN       0.605       0.373
#
#    2023-01-05  2023-01-06  2023-01-07  2023-01-08  ...  2023-09-16  \
# 0       0.375       0.322         NaN         NaN  ...       1.128
# 1       0.375       0.336         NaN         NaN  ...       1.141
# 2       0.373       0.342         NaN         NaN  ...       1.142
# 3       0.385       0.338         NaN         NaN  ...       1.175
# 4       0.398       0.355         NaN         NaN  ...       1.211
#
#    2023-09-17  2023-09-18  2023-09-19  2023-09-20  2023-09-21  2023-09-22  \
# ...

# %%
df_2023.columns
# Out:
# Index(['latitude', 'longitude', '2023-01-01', '2023-01-02', '2023-01-03',
#        '2023-01-04', '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#        ...
#        '2023-09-16', '2023-09-17', '2023-09-18', '2023-09-19', '2023-09-20',
#        '2023-09-21', '2023-09-22', '2023-09-23', '2023-09-24', '2023-09-25'],
#       dtype='object', length=250)

# %%
df_2018 = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv")
df_2018.head()
df = df_2018

# %%
df_2018 = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv")
df_2018.head()
df = df_2018
import pandas as pd

# Assuming you already have a DataFrame named 'df' with your data
# Replace 'df' with your actual DataFrame name

# Select columns for which you want to calculate the mean (excluding the first two columns)
aod_df = df.iloc[:, 2:]

# Calculate the mean for each column
mean_aod_series = aod_df.mean()

# Create a new DataFrame with the means
mean_aod_df = pd.DataFrame(mean_aod_series, columns=['Mean_AOD'])

# Reset the index to use the dates as the index
mean_aod_df.reset_index(inplace=True)

# Rename the columns for clarity
mean_aod_df.columns = ['Date', 'Mean_AOD']

# Print or use the mean_aod_df as needed
print(mean_aod_df)
# Out:
#            Date  Mean_AOD
# 0    2018-01-01       NaN
# 1    2018-01-02  0.346802
# 2    2018-01-03       NaN
# 3    2018-01-04  0.566856
# 4    2018-01-05  1.682498
# ..          ...       ...
# 360  2018-12-27  0.836552
# 361  2018-12-28       NaN
# 362  2018-12-29  0.883863
# 363  2018-12-30       NaN
# 364  2018-12-31  1.311591
#
# [365 rows x 2 columns]

# %%
mean_aod_df["Mean_AOD"].isna().sum()
# Out:
# 165

# %%
df_2018 = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv")
df_2018.head()
df = df_2018
import pandas as pd

# Assuming you already have a DataFrame named 'df' with your data
# Replace 'df' with your actual DataFrame name

# Select columns for which you want to calculate the mean (excluding the first two columns)
aod_df = df.iloc[:, 2:]

# Calculate the mean for each column
mean_aod_series = aod_df.mean()

# Create a new DataFrame with the means
mean_aod_df = pd.DataFrame(mean_aod_series, columns=['Mean_AOD'])

# Reset the index to use the dates as the index
mean_aod_df.reset_index(inplace=True)

# Rename the columns for clarity
mean_aod_df.columns = ['Date', 'Mean_AOD']

# Print or use the mean_aod_df as needed
print(mean_aod_df)

# Assuming 'mean_aod_df' is your DataFrame with NaN values in 'Mean_AOD' column

# Remove rows with NaN values in the 'Mean_AOD' column
mean_aod_df_cleaned = mean_aod_df.dropna(subset=['Mean_AOD'])

# Reset the index if needed
mean_aod_df_cleaned.reset_index(drop=True, inplace=True)

# Print or use 'mean_aod_df_cleaned' as needed
print(mean_aod_df_cleaned)
# Out:
#            Date  Mean_AOD
# 0    2018-01-01       NaN
# 1    2018-01-02  0.346802
# 2    2018-01-03       NaN
# 3    2018-01-04  0.566856
# 4    2018-01-05  1.682498
# ..          ...       ...
# 360  2018-12-27  0.836552
# 361  2018-12-28       NaN
# 362  2018-12-29  0.883863
# 363  2018-12-30       NaN
# 364  2018-12-31  1.311591
#
# [365 rows x 2 columns]
#            Date  Mean_AOD
# 0    2018-01-02  0.346802
# 1    2018-01-04  0.566856
# 2    2018-01-05  1.682498
# 3    2018-01-06  1.775824
# 4    2018-01-07  1.168703
# ..          ...       ...
# 195  2018-12-24  1.736963
# 196  2018-12-25  1.057200
# 197  2018-12-27  0.836552
# 198  2018-12-29  0.883863
# 199  2018-12-31  1.311591
#
# [200 rows x 2 columns]

# %%
df_2018 = pd.read_csv("/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv")
df_2018.head()
df = df_2018
import pandas as pd

# Assuming you already have a DataFrame named 'df' with your data
# Replace 'df' with your actual DataFrame name

# Select columns for which you want to calculate the mean (excluding the first two columns)
aod_df = df.iloc[:, 2:]

# Calculate the mean for each column
mean_aod_series = aod_df.mean()

# Create a new DataFrame with the means
mean_aod_df = pd.DataFrame(mean_aod_series, columns=['Mean_AOD'])

# Reset the index to use the dates as the index
mean_aod_df.reset_index(inplace=True)

# Rename the columns for clarity
mean_aod_df.columns = ['Date', 'Mean_AOD']

# Print or use the mean_aod_df as needed
print(mean_aod_df)

# Assuming 'mean_aod_df' is your DataFrame with NaN values in 'Mean_AOD' column

# Remove rows with NaN values in the 'Mean_AOD' column
mean_aod_df_cleaned = mean_aod_df.dropna(subset=['Mean_AOD'])

# Reset the index if needed
mean_aod_df_cleaned.reset_index(drop=True, inplace=True)

# Print or use 'mean_aod_df_cleaned' as needed
print(mean_aod_df_cleaned)

import matplotlib.pyplot as plt

# Assuming 'mean_aod_df_cleaned' contains your cleaned DataFrame
# 'Date' should be a datetime type, if it's not, convert it to datetime first
mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned['Date'])

# Create the time series plot
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
plt.plot(mean_aod_df_cleaned['Date'], mean_aod_df_cleaned['Mean_AOD'], marker='o', linestyle='-')
plt.xlabel('Date')
plt.ylabel('Mean AOD Value')
plt.title('Time Series Plot of Mean AOD')
plt.grid(True)  # Add grid lines if desired
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()
# Out:
#            Date  Mean_AOD
# 0    2018-01-01       NaN
# 1    2018-01-02  0.346802
# 2    2018-01-03       NaN
# 3    2018-01-04  0.566856
# 4    2018-01-05  1.682498
# ..          ...       ...
# 360  2018-12-27  0.836552
# 361  2018-12-28       NaN
# 362  2018-12-29  0.883863
# 363  2018-12-30       NaN
# 364  2018-12-31  1.311591
#
# [365 rows x 2 columns]
#            Date  Mean_AOD
# 0    2018-01-02  0.346802
# 1    2018-01-04  0.566856
# 2    2018-01-05  1.682498
# 3    2018-01-06  1.775824
# 4    2018-01-07  1.168703
# ..          ...       ...
# 195  2018-12-24  1.736963
# 196  2018-12-25  1.057200
# 197  2018-12-27  0.836552
# 198  2018-12-29  0.883863
# 199  2018-12-31  1.311591
#
# [200 rows x 2 columns]
# /tmp/ipykernel_405883/2713758925.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a list to store DataFrames for each CSV file
dataframes = []

# List of file paths for the six CSV files
file_paths = [
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2019_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2020_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2021_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2022_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2023_sorted_dates.csv",
]

# Load each CSV file into a DataFrame and store them in the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Create subplots for the six plots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))  # 2 rows, 3 columns

# Loop through the DataFrames and plot them in the subplots
for i, df in enumerate(dataframes):
    row = i // 3  # Determine the row of the subplot
    col = i % 3   # Determine the column of the subplot
    # Select columns for which you want to calculate the mean (excluding the first two columns)
    aod_df = df.iloc[:, 2:]
    
    # Calculate the mean for each column
    mean_aod_series = aod_df.mean()
    
    # Create a new DataFrame with the means
    mean_aod_df = pd.DataFrame(mean_aod_series, columns=['Mean_AOD'])
    
    # Reset the index to use the dates as the index
    mean_aod_df.reset_index(inplace=True)
    
    # Rename the columns for clarity
    mean_aod_df.columns = ['Date', 'Mean_AOD']

    # Remove rows with NaN values in the 'Mean_AOD' column
    mean_aod_df_cleaned = mean_aod_df.dropna(subset=['Mean_AOD'])

    # Reset the index if needed
    mean_aod_df_cleaned.reset_index(drop=True, inplace=True)
    
    # Print or use 'mean_aod_df_cleaned' as needed
    #print(mean_aod_df_cleaned)
    
    import matplotlib.pyplot as plt
    
    # Assuming 'mean_aod_df_cleaned' contains your cleaned DataFrame
    # 'Date' should be a datetime type, if it's not, convert it to datetime first
    mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned['Date'])

    # Plot the mean AOD values in the corresponding subplot
    axes[row, col].plot(mean_aod_df_cleaned["Date"], mean_aod_df_cleaned['Mean_AOD'], marker='o', linestyle='-')
    axes[row, col].set_xlabel('Date')
    axes[row, col].set_ylabel('Mean AOD Value')
    axes[row, col].set_title(f'Plot {i + 1}')
    axes[row, col].grid(True)
    axes[row, col].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()

# Show the combined plot with six subplots
plt.show()
# Out:
# /tmp/ipykernel_405883/3806289511.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned['Date'])
# /tmp/ipykernel_405883/3806289511.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned['Date'])
# /tmp/ipykernel_405883/3806289511.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a list to store DataFrames for each CSV file
dataframes = []

# List of file paths for the six CSV files
file_paths = [
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2019_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2020_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2021_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2022_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2023_sorted_dates.csv",
]

# Load each CSV file into a DataFrame and store them in the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Create subplots for the six plots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))  # 2 rows, 3 columns

# Loop through the DataFrames and plot them in the subplots
for i, df in enumerate(dataframes):
    row = i // 3  # Determine the row of the subplot
    col = i % 3   # Determine the column of the subplot

    # Select columns for which you want to calculate the mean (excluding the first two columns)
    aod_df = df.iloc[:, 2:]

    # Calculate the mean for each column
    mean_aod_series = aod_df.mean()

    # Create a new DataFrame with the means
    mean_aod_df = pd.DataFrame(mean_aod_series, columns=['Mean_AOD'])

    # Remove rows with NaN values in the 'Mean_AOD' column
    mean_aod_df_cleaned = mean_aod_df.dropna(subset=['Mean_AOD'])

    # Reset the index if needed
    mean_aod_df_cleaned.reset_index(drop=True, inplace=True)

    # Convert the 'Date' column to datetime
    mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned.index)  # Assuming index represents dates

    # Plot the mean AOD values in the corresponding subplot
    axes[row, col].plot(mean_aod_df_cleaned['Date'], mean_aod_df_cleaned['Mean_AOD'], marker='o', linestyle='-')
    axes[row, col].set_xlabel('Date')
    axes[row, col].set_ylabel('Mean AOD Value')
    axes[row, col].set_title(f'Plot {i + 1}')
    axes[row, col].grid(True)
    axes[row, col].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()

# Show the combined plot with six subplots
plt.show()
# Out:
# /tmp/ipykernel_405883/2982448496.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned.index)  # Assuming index represents dates
# /tmp/ipykernel_405883/2982448496.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned.index)  # Assuming index represents dates
# /tmp/ipykernel_405883/2982448496.py:46: SettingWithCopyWarning:
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a list to store DataFrames for each CSV file
dataframes = []

# List of file paths for the six CSV files
file_paths = [
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2018_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2019_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2020_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2021_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2022_sorted_dates.csv",
    "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/merged_data_2023_sorted_dates.csv",
]

# Load each CSV file into a DataFrame and store them in the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dataframes.append(df)

# Create subplots for the six plots
fig, axes = plt.subplots(2, 3, figsize=(15, 10))  # 2 rows, 3 columns

# Loop through the DataFrames and plot them in the subplots
for i, df in enumerate(dataframes):
    row = i // 3  # Determine the row of the subplot
    col = i % 3   # Determine the column of the subplot
    # Select columns for which you want to calculate the mean (excluding the first two columns)
    aod_df = df.iloc[:, 2:]
    
    # Calculate the mean for each column
    mean_aod_series = aod_df.mean()
    
    # Create a new DataFrame with the means
    mean_aod_df = pd.DataFrame(mean_aod_series, columns=['Mean_AOD'])
    
    # Reset the index to use the dates as the index
    mean_aod_df.reset_index(inplace=True)
    
    # Rename the columns for clarity
    mean_aod_df.columns = ['Date', 'Mean_AOD']

    # Remove rows with NaN values in the 'Mean_AOD' column
    mean_aod_df_cleaned = mean_aod_df.dropna(subset=['Mean_AOD'])

    # Reset the index if needed
    mean_aod_df_cleaned.reset_index(drop=True, inplace=True)
    
    # Convert 'Date' to datetime
    mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned['Date'])

    # Plot the mean AOD values in the corresponding subplot
    axes[row, col].plot(mean_aod_df_cleaned["Date"], mean_aod_df_cleaned['Mean_AOD'], marker='o', linestyle='-')
    axes[row, col].set_xlabel('Date')
    axes[row, col].set_ylabel('Mean AOD Value')
    axes[row, col].set_title(f'Plot {i + 1}')
    axes[row, col].grid(True)
    axes[row, col].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()

# Save the combined plot with six subplots to a file in the specified folder
output_folder = "/home/sysadm/Desktop/Term project/csvfile with whom i kriging/"  # Replace with your desired folder path
output_file = f"{output_folder}/combined_plots.png"  # Specify the output file name and format

plt.savefig(output_file)

# Show the combined plot with six subplots
plt.show()
# Out:
# /tmp/ipykernel_405883/636081141.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned['Date'])
# /tmp/ipykernel_405883/636081141.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mean_aod_df_cleaned['Date'] = pd.to_datetime(mean_aod_df_cleaned['Date'])
# /tmp/ipykernel_405883/636081141.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
