# %%
import pandas as pd

# %%
df_2018 = pd.read_csv("/home/sysadm/Desktop/Term project/Modis_2018_2019_2020csv_aod/AOD_extract_ipynb/raw_data_allyear/kriging_33_percentage_csv/2018_below_33_percentage_kriging.csv")

# %%
df_2018.head()
# Out:
#    latitude  longitude  2018-01-02  2018-01-04  2018-01-05  2018-01-06  \
# 0    28.414     77.171       0.322    0.816000       1.422       2.179
# 1    28.414     77.181       0.305    0.818462       1.360       2.154
# 2    28.414     77.192       0.293    0.824012       1.337       2.130
# 3    28.414     77.202       0.305    0.833312       1.314       2.129
# 4    28.414     77.213       0.319    0.848415       1.327       2.147
#
#    2018-01-07  2018-01-09  2018-01-13  2018-01-14  ...  2018-12-15  \
# 0       1.117       0.625       0.206       0.441  ...       0.652
# 1       1.069       0.615       0.201       0.430  ...       0.647
# 2       1.059       0.603       0.205       0.437  ...       0.665
# 3       1.047       0.624       0.222       0.453  ...       0.663
# 4       1.050       0.653       0.241       0.453  ...       0.681
#
#    2018-12-16  2018-12-18  2018-12-20  2018-12-22  2018-12-23  2018-12-24  \
# ...

# %%
df_2019 = pd.read_csv("/home/sysadm/Desktop/Term project/Modis_2018_2019_2020csv_aod/AOD_extract_ipynb/raw_data_allyear/kriging_33_percentage_csv/2019_below_33_percentage_kriging.csv")

# %%
df_2019.head()
# Out:
#    latitude  longitude  2019-01-05  2019-01-07  2019-01-08  2019-01-10  \
# 0    28.414     77.171    1.975559    0.674077       1.132       0.862
# 1    28.414     77.181    1.930000    0.685184       1.105       0.846
# 2    28.414     77.192    1.910000    0.696978       1.101       0.840
# 3    28.414     77.202    1.925000    0.709000       1.104       0.838
# 4    28.414     77.213    1.959000    0.716712       1.135       0.858
#
#    2019-01-14  2019-01-16  2019-01-17  2019-01-26  ...  2019-11-25  \
# 0       0.530    0.550315       1.123       0.595  ...       0.444
# 1       0.525    0.555699       1.039       0.559  ...       0.449
# 2       0.527    0.561571       1.128       0.553  ...       0.452
# 3       0.525    0.594000       1.058       0.560  ...       0.456
# 4       0.536    0.568611       1.065       0.593  ...       0.479
#
#    2019-11-28  2019-11-30  2019-12-02  2019-12-03  2019-12-07  2019-12-09  \
# ...

# %%
df_2020 = pd.read_csv("/home/sysadm/Desktop/Term project/Modis_2018_2019_2020csv_aod/AOD_extract_ipynb/raw_data_allyear/kriging_33_percentage_csv/2020_below_33_percentage_kriging.csv")

# %%
df_2020.head()
# Out:
#    latitude  longitude  2020-03-07  2020-12-07  2020-01-04  2020-01-19  \
# 0    28.414     77.171       0.399       1.503       1.092     0.65200
# 1    28.414     77.181       0.395       1.433       1.077     0.66500
# 2    28.414     77.192       0.390       1.476       1.085     0.66300
# 3    28.414     77.202       0.408       1.371       1.106     0.68300
# 4    28.414     77.213       0.439       1.463       1.157     0.68767
#
#    2020-01-22  2020-01-24  2020-01-26  2020-01-28  ...  2020-12-02  \
# 0       1.109     0.54785    0.735000       0.340  ...       0.477
# 1       1.070     0.54785    0.756000       0.341  ...       0.481
# 2       1.051     0.54785    0.756000       0.337  ...       0.491
# 3       1.067     0.54785    0.767311       0.354  ...       0.506
# 4       1.093     0.54785    0.785799       0.375  ...       0.525
#
#    2020-12-04  2020-12-05  2020-12-16  2020-12-18  2020-12-21  2020-12-23  \
# ...

# %%
df_2021 = pd.read_csv("/home/sysadm/Desktop/Term project/Modis_2018_2019_2020csv_aod/AOD_extract_ipynb/raw_data_allyear/kriging_33_percentage_csv/2021_below_33_percentage_kriging.csv")

# %%
df_2021.head()
# Out:
#    latitude  longitude  2021-01-01  2021-01-10  2021-01-12  2021-01-13  \
# 0    28.414     77.171       0.586       0.373       0.185    0.477808
# 1    28.414     77.181       0.570       0.375       0.178    0.474682
# 2    28.414     77.192       0.561       0.376       0.178    0.470952
# 3    28.414     77.202       0.581       0.394       0.194    0.467632
# 4    28.414     77.213       0.595       0.425       0.214    0.463414
#
#    2021-01-17  2021-01-21  2021-01-22  2021-01-26  ...  2021-12-05  \
# 0       0.423       0.455       0.645       0.467  ...       0.747
# 1       0.403       0.455       0.623       0.454  ...       0.747
# 2       0.394       0.459       0.627       0.438  ...       0.749
# 3       0.423       0.479       0.616       0.458  ...       0.770
# 4       0.459       0.501       0.625       0.466  ...       0.791
#
#    2021-12-07  2021-12-08  2021-12-10  2021-12-12  2021-12-14  2021-12-15  \
# ...

# %%
df_2022 = pd.read_csv("/home/sysadm/Desktop/Term project/Modis_2018_2019_2020csv_aod/AOD_extract_ipynb/raw_data_allyear/kriging_33_percentage_csv/2022_below_33_percentage_kriging.csv")

# %%
df_2022.head()
# Out:
#    latitude  longitude  2022-03-21  2022-05-23  2022-10-21  2022-11-03  \
# 0    28.414     77.171       0.929       2.828       0.502       0.948
# 1    28.414     77.181       0.889       2.895       0.522       0.967
# 2    28.414     77.192       0.897       2.874       0.526       0.989
# 3    28.414     77.202       0.923       2.714       0.532       1.022
# 4    28.414     77.213       0.960       2.855       0.543       1.061
#
#    2022-12-04  2022-01-02  2022-01-11  2022-01-13  ...  2022-12-06  \
# 0       0.974       1.001       0.000       0.122  ...       0.628
# 1       1.024       0.898       0.006       0.093  ...       0.652
# 2       0.991       0.883       0.042       0.076  ...       0.649
# 3       0.958       0.867       0.053       0.070  ...       0.648
# 4       0.983       0.860       0.075       0.079  ...       0.655
#
#    2022-12-08  2022-12-10  2022-12-11  2022-12-13  2022-12-15  2022-12-17  \
# ...

# %%
df_2023 = pd.read_csv("/home/sysadm/Desktop/Term project/Modis_2018_2019_2020csv_aod/AOD_extract_ipynb/raw_data_allyear/kriging_33_percentage_csv/2023_below_33_percentage_kriging.csv")

# %%
df_2023.head()
# Out:
#    latitude  longitude  2023-01-04  2023-02-04  2023-02-06  2023-03-07  \
# 0    28.414     77.171       0.339       0.665       0.715       0.609
# 1    28.414     77.181       0.349       0.662       0.664       0.623
# 2    28.414     77.192       0.363       0.662       0.664       0.637
# 3    28.414     77.202       0.368       0.706       0.649       0.634
# 4    28.414     77.213       0.373       0.664       0.662       0.639
#
#    2021-02-22  2021-02-23  2021-02-25  2021-02-27  ...  2023-08-07  \
# 0     0.44400       0.538       0.794       0.914  ...       1.186
# 1     0.43361       0.508       0.806       0.857  ...       1.126
# 2     0.46700       0.561       0.807       0.842  ...       1.124
# 3     0.48500       0.523       0.843       0.871  ...       1.146
# 4     0.49100       0.573       0.859       0.899  ...       1.187
#
#    2023-08-11  2023-08-12  2023-08-16  2023-08-17  2023-09-09  2023-09-10  \
# ...

# %%
# By using DataFrame.merge()
df = df_2018.merge(df_2019,on=['latitude',"longitude"]).merge(df_2020,on=["latitude","longitude"]).merge(df_2021,on = ["latitude","longitude"]).merge(df_2022,on = ["latitude","longitude"]).merge(df_2023,on = ["latitude","longitude"])
print("Afetr merging the multiple DataFrames:\n", df)
# Out:
# Afetr merging the multiple DataFrames:
#        latitude  longitude  2018-01-02  2018-01-04  2018-01-05  2018-01-06  \
# 0       28.414     77.171       0.322    0.816000    1.422000       2.179
# 1       28.414     77.181       0.305    0.818462    1.360000       2.154
# 2       28.414     77.192       0.293    0.824012    1.337000       2.130
# 3       28.414     77.202       0.305    0.833312    1.314000       2.129
# 4       28.414     77.213       0.319    0.848415    1.327000       2.147
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.235    0.381000    1.622980       1.339
# 1346    28.864     77.088       0.246    0.373000    1.633852       1.259
# 1347    28.864     77.098       0.248    0.375000    1.647527       1.258
# 1348    28.864     77.109       0.246    0.375000    1.668693       1.244
# 1349    28.874     77.088       0.241    0.391000    1.633852       1.333
#
# ...

# %%
df
# Out:
#       latitude  longitude  2018-01-02  2018-01-04  2018-01-05  2018-01-06  \
# 0       28.414     77.171       0.322    0.816000    1.422000       2.179
# 1       28.414     77.181       0.305    0.818462    1.360000       2.154
# 2       28.414     77.192       0.293    0.824012    1.337000       2.130
# 3       28.414     77.202       0.305    0.833312    1.314000       2.129
# 4       28.414     77.213       0.319    0.848415    1.327000       2.147
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.235    0.381000    1.622980       1.339
# 1346    28.864     77.088       0.246    0.373000    1.633852       1.259
# 1347    28.864     77.098       0.248    0.375000    1.647527       1.258
# 1348    28.864     77.109       0.246    0.375000    1.668693       1.244
# 1349    28.874     77.088       0.241    0.391000    1.633852       1.333
#
#       2018-01-07  2018-01-09  2018-01-13  2018-01-14  ...  2023-08-07  \
# ...

# %% [markdown]
# # Remove the duplicate columns

# %%
#df.columns.duplicated()

# %%
import pandas as pd


# Find and drop duplicate columns
df = df.loc[:, ~df.columns.duplicated()]
df
# Now, df contains only unique columns
# Out:
#       latitude  longitude  2018-01-02  2018-01-04  2018-01-05  2018-01-06  \
# 0       28.414     77.171       0.322    0.816000    1.422000       2.179
# 1       28.414     77.181       0.305    0.818462    1.360000       2.154
# 2       28.414     77.192       0.293    0.824012    1.337000       2.130
# 3       28.414     77.202       0.305    0.833312    1.314000       2.129
# 4       28.414     77.213       0.319    0.848415    1.327000       2.147
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.235    0.381000    1.622980       1.339
# 1346    28.864     77.088       0.246    0.373000    1.633852       1.259
# 1347    28.864     77.098       0.248    0.375000    1.647527       1.258
# 1348    28.864     77.109       0.246    0.375000    1.668693       1.244
# 1349    28.874     77.088       0.241    0.391000    1.633852       1.333
#
#       2018-01-07  2018-01-09  2018-01-13  2018-01-14  ...  2023-08-07  \
# ...

# %%
df.to_csv("/home/sysadm/Desktop/Term project/Modis_2018_2019_2020csv_aod/AOD_extract_ipynb/raw_data_allyear/merged_all_year.csv",index = False)

# %%
df
# Out:
#       latitude  longitude  2018-01-02  2018-01-04  2018-01-05  2018-01-06  \
# 0       28.414     77.171       0.322    0.816000    1.422000       2.179
# 1       28.414     77.181       0.305    0.818462    1.360000       2.154
# 2       28.414     77.192       0.293    0.824012    1.337000       2.130
# 3       28.414     77.202       0.305    0.833312    1.314000       2.129
# 4       28.414     77.213       0.319    0.848415    1.327000       2.147
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.235    0.381000    1.622980       1.339
# 1346    28.864     77.088       0.246    0.373000    1.633852       1.259
# 1347    28.864     77.098       0.248    0.375000    1.647527       1.258
# 1348    28.864     77.109       0.246    0.375000    1.668693       1.244
# 1349    28.874     77.088       0.241    0.391000    1.633852       1.333
#
#       2018-01-07  2018-01-09  2018-01-13  2018-01-14  ...  2023-08-07  \
# ...
