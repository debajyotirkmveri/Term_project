# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load Data
# Assuming your data is in a CSV file, load it into a DataFrame
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2018_sorted_dates.csv')
df.head()
# Out:
#    latitude  longitude  2018-01-01  2018-01-02  2018-01-03  2018-01-04  \
# 0    28.414     77.171       0.282       0.322       0.312       0.816
# 1    28.414     77.181       0.287       0.305       0.314         NaN
# 2    28.414     77.192       0.293       0.293       0.317         NaN
# 3    28.414     77.202       0.298       0.305       0.323         NaN
# 4    28.414     77.213       0.307       0.319       0.335         NaN
#
#    2018-01-05  2018-01-06  2018-01-07  2018-01-08  ...  2018-12-22  \
# 0         NaN       2.179       1.117       0.453  ...       0.552
# 1         NaN       2.154       1.069       0.455  ...       0.543
# 2         NaN       2.130       1.059       0.465  ...       0.550
# 3         NaN       2.129       1.047       0.480  ...       0.570
# 4         NaN       2.147       1.050       0.497  ...       0.591
#
#    2018-12-23  2018-12-24  2018-12-25  2018-12-26  2018-12-27  2018-12-28  \
# ...

# %%
total_nan_values_except_first_two = df.iloc[:, 2:].isna().sum()
print(total_nan_values_except_first_two)
# Out:
# 2018-01-01       0
# 2018-01-02      55
# 2018-01-03      11
# 2018-01-04     116
# 2018-01-05    1103
#               ...
# 2018-12-27      33
# 2018-12-28       0
# 2018-12-29      42
# 2018-12-30       3
# 2018-12-31     793
# Length: 365, dtype: int64

# %%
# Calculate the number of NaN values in each column, excluding the first two columns
total_nan_values_except_first_two = df.iloc[:, 2:].isna().sum()

# Check which columns have 1350 NaN values
columns_with_1350_nans = total_nan_values_except_first_two[total_nan_values_except_first_two == 1350]

# Print the columns with 1350 NaN values
print(columns_with_1350_nans)
len(columns_with_1350_nans)
# Out:
# 2018-01-28    1350
# 2018-01-29    1350
# 2018-01-31    1350
# 2018-02-05    1350
# 2018-02-11    1350
# 2018-02-14    1350
# 2018-02-15    1350
# 2018-02-23    1350
# 2018-03-03    1350
# 2018-03-06    1350
# 2018-03-25    1350
# 2018-04-09    1350
# 2018-04-14    1350
# 2018-04-19    1350
# 2018-06-10    1350
# 2018-06-28    1350
# 2018-06-29    1350
# 2018-06-30    1350
# 2018-07-01    1350
# 2018-07-04    1350
# 2018-07-05    1350
# 2018-07-11    1350
# 2018-07-12    1350
# 2018-07-15    1350
# 2018-07-16    1350
# 2018-07-17    1350
# 2018-07-18    1350
# 2018-07-19    1350
# 2018-07-20    1350
# 2018-07-21    1350
# 2018-07-22    1350
# 2018-07-23    1350
# 2018-07-24    1350
# 2018-07-26    1350
# 2018-07-27    1350
# 2018-08-04    1350
# 2018-08-06    1350
# 2018-08-09    1350
# 2018-08-13    1350
# 2018-08-18    1350
# 2018-08-19    1350
# 2018-08-21    1350
# 2018-08-27    1350
# 2018-09-09    1350
# 2018-11-11    1350
# 2018-11-13    1350
# 2018-11-27    1350
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame with the data you provided

# Calculate the number of NaN values in each column, excluding the first two columns
total_nan_values_except_first_two = df.iloc[:, 2:].isna().sum()

# Identify columns with 1350 NaN values
columns_with_1350_nans = total_nan_values_except_first_two[total_nan_values_except_first_two == 1350]

# Remove columns with 1350 NaN values from the DataFrame
df_cleaned = df.drop(columns=columns_with_1350_nans.index)

# Print the resulting DataFrame
print(df_cleaned)
# Out:
#       latitude  longitude  2018-01-01  2018-01-02  2018-01-03  2018-01-04  \
# 0       28.414     77.171       0.282       0.322       0.312       0.816
# 1       28.414     77.181       0.287       0.305       0.314         NaN
# 2       28.414     77.192       0.293       0.293       0.317         NaN
# 3       28.414     77.202       0.298       0.305       0.323         NaN
# 4       28.414     77.213       0.307       0.319       0.335         NaN
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.292       0.235       0.304       0.381
# 1346    28.864     77.088       0.289       0.246       0.304       0.373
# 1347    28.864     77.098       0.287       0.248       0.302       0.375
# 1348    28.864     77.109       0.285       0.246       0.293       0.375
# 1349    28.874     77.088       0.287       0.241       0.314       0.391
#
#       2018-01-05  2018-01-06  2018-01-07  2018-01-08  ...  2018-12-22  \
# ...

# %%
df_cleaned
# Out:
#       latitude  longitude  2018-01-01  2018-01-02  2018-01-03  2018-01-04  \
# 0       28.414     77.171       0.282       0.322       0.312       0.816
# 1       28.414     77.181       0.287       0.305       0.314         NaN
# 2       28.414     77.192       0.293       0.293       0.317         NaN
# 3       28.414     77.202       0.298       0.305       0.323         NaN
# 4       28.414     77.213       0.307       0.319       0.335         NaN
# ...        ...        ...         ...         ...         ...         ...
# 1345    28.864     77.078       0.292       0.235       0.304       0.381
# 1346    28.864     77.088       0.289       0.246       0.304       0.373
# 1347    28.864     77.098       0.287       0.248       0.302       0.375
# 1348    28.864     77.109       0.285       0.246       0.293       0.375
# 1349    28.874     77.088       0.287       0.241       0.314       0.391
#
#       2018-01-05  2018-01-06  2018-01-07  2018-01-08  ...  2018-12-22  \
# ...

# %%
import matplotlib.pyplot as plt
# You can plot it as a time series
plt.figure(figsize=(12, 6))
plt.plot(total_nan_values_except_first_two.index, total_nan_values_except_first_two.values, marker='o', linestyle='-')
plt.title('Count of NaN Values Over Time')
plt.xlabel('Date')
plt.ylabel('Count of NaN Values')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have already calculated total_nan_values_except_first_two

# Create a date range from the index of total_nan_values_except_first_two
date_range = total_nan_values_except_first_two.index

# Calculate the number of data points in each 30-day interval
interval_length = 30
num_intervals = len(date_range) // interval_length

# Initialize lists to store interval dates and counts
interval_dates = []
interval_counts = []

# Iterate through the intervals and calculate the counts
for i in range(num_intervals):
    start_idx = i * interval_length
    end_idx = (i + 1) * interval_length
    interval_dates.append(date_range[start_idx])
    interval_counts.append(total_nan_values_except_first_two[start_idx:end_idx].sum())

# Create a DataFrame for the intervals
interval_data = {'Interval Start Date': interval_dates, 'Count of NaN Values': interval_counts}
interval_df = pd.DataFrame(interval_data)

# Plot the time series
plt.figure(figsize=(12, 6))
plt.plot(interval_df['Interval Start Date'], interval_df['Count of NaN Values'], marker='o', linestyle='-')
plt.title('Count of NaN Values Over 30-Day Intervals')
plt.xlabel('Interval Start Date')
plt.ylabel('Count of NaN Values')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have already calculated total_nan_values_except_first_two

# Convert the index to a datetime object if it's not already
total_nan_values_except_first_two.index = pd.to_datetime(total_nan_values_except_first_two.index)

# Group the data by month
monthly_counts = total_nan_values_except_first_two.resample('M').sum()

# Create a time series plot for each month
plt.figure(figsize=(12, 6))
for month, count in monthly_counts.items():
    plt.plot(month, count, marker='o', linestyle='-', label=month.strftime('%B'))

plt.title('Count of NaN Values by Month')
plt.xlabel('Month')
plt.ylabel('Count of NaN Values')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.legend()
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have already calculated total_nan_values_except_first_two

# Convert the index to a datetime object if it's not already
total_nan_values_except_first_two.index = pd.to_datetime(total_nan_values_except_first_two.index)

# Group the data by month
monthly_counts = total_nan_values_except_first_two.resample('M').sum()

# Iterate through the data and create separate plots for each month's first 31 days
for month, count in monthly_counts.items():
    # Get the year and month of the current data
    year = month.year
    month_num = month.month

    # Create a mask for the first 31 days of the current month
    mask = (total_nan_values_except_first_two.index.year == year) & (total_nan_values_except_first_two.index.month == month_num) & (total_nan_values_except_first_two.index.day <= 31)
    data_for_month = total_nan_values_except_first_two[mask]

    plt.figure(figsize=(12, 6))
    plt.plot(data_for_month.index, data_for_month.values, marker='o', linestyle='-')
    plt.title(f'Count of NaN Values for {month.strftime("%B")}')
    plt.xlabel('Date')
    plt.ylabel('Count of NaN Values')
    plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Assuming you have already calculated total_nan_values_except_first_two
# Convert the index to a datetime object if it's not already
total_nan_values_except_first_two.index = pd.to_datetime(total_nan_values_except_first_two.index)

# Define the date range you want to investigate
start_date = '2018-11-05'
end_date = '2018-11-13'

# Use boolean indexing to filter the NaN values within the specified date range
nan_values_in_date_range = total_nan_values_except_first_two[(total_nan_values_except_first_two.index >= start_date) & (total_nan_values_except_first_two.index <= end_date)]

# Print the NaN values for the specified date range
print(nan_values_in_date_range)
# Out:
# 2018-11-05    1297
# 2018-11-06      10
# 2018-11-07      34
# 2018-11-08       0
# 2018-11-09      20
# 2018-11-10      73
# 2018-11-11    1350
# 2018-11-12     387
# 2018-11-13    1350
# dtype: int64

# %%
total_nan_values_except_first_two = df.iloc[:, 2:].isna().sum()
print(total_nan_values_except_first_two)
# Out:
# 2018-01-01       0
# 2018-01-02      55
# 2018-01-03      11
# 2018-01-04     116
# 2018-01-05    1103
#               ...
# 2018-12-27      33
# 2018-12-28       0
# 2018-12-29      42
# 2018-12-30       3
# 2018-12-31     793
# Length: 365, dtype: int64

# %%
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import plotly.express as px

# Assuming you have already calculated total_nan_values_except_first_two

# Convert the index to a datetime object if it's not already
total_nan_values_except_first_two.index = pd.to_datetime(total_nan_values_except_first_two.index)

# Group the data by month
monthly_counts = total_nan_values_except_first_two.resample('M').sum()

# Iterate through the data and create separate plots for each month's first 31 days
for month, count in monthly_counts.items():
    # Get the year and month of the current data
    year = month.year
    month_num = month.month

    # Create a mask for the first 31 days of the current month
    mask = (total_nan_values_except_first_two.index.year == year) & (total_nan_values_except_first_two.index.month == month_num) & (total_nan_values_except_first_two.index.day <= 31)
    data_for_month = total_nan_values_except_first_two[mask]

    # Create a Plotly figure
    fig = px.line(data_for_month, x=data_for_month.index, y=data_for_month.values, title=f'Count of NaN Values for {month.strftime("%B")}')

    # Customize the figure (optional)
    fig.update_xaxes(title_text='Date')
    fig.update_yaxes(title_text='Count of NaN Values')

    # Save the plot as an HTML file
    fig.write_html(f'/home/sysadm/Desktop/Term project/2018_EDA/2018_nan_value plothtml/count_of_nan_values_{month.strftime("%B")}.html')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px

# Assuming you have already calculated nan_values_in_date_range

# Convert the index to a datetime object if it's not already
nan_values_in_date_range.index = pd.to_datetime(nan_values_in_date_range.index)

# Create a time series plot of the NaN values
plt.figure(figsize=(12, 6))
plt.plot(nan_values_in_date_range.index, nan_values_in_date_range.values, marker='o', linestyle='-')
plt.title('NaN Values Between November 5th and November 13th')
plt.xlabel('Date')
plt.ylabel('Count of NaN Values')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.tight_layout()

# Save the Matplotlib plot as an HTML file
plt.savefig('nan_values_plot.png')

# Create a Plotly figure for the same data
fig = px.line(nan_values_in_date_range, x=nan_values_in_date_range.index, y=nan_values_in_date_range.values, title='NaN Values Between November 5th and November 13th')

# Customize the figure (optional)
fig.update_xaxes(title_text='Date')
fig.update_yaxes(title_text='Count of NaN Values')

# Save the Plotly plot as an HTML file
fig.write_html('/home/sysadm/Desktop/Term project/2018_EDA/3_15th november html nan values/nan_values_plot.html')

# Show the Plotly plot (optional)
# fig.show()

# %%
data = df

# %%
df = data

# Filter locations where all AOD values are NaN for the first day
nan_locations_df = df[(df['2018-01-02'].isna())]

# Print the DataFrame with latitude and longitude for locations with NaN values for the first day
print(nan_locations_df[['latitude', 'longitude']])
# Out:
#       latitude  longitude
# 78      28.482     77.213
# 90      28.492     77.213
# 91      28.492     77.223
# 92      28.492     77.233
# 111     28.502     77.213
# 164     28.522     76.994
# 165     28.522     77.005
# 166     28.522     77.015
# 196     28.531     76.891
# 221     28.531     77.181
# 314     28.551     77.202
# 326     28.561     76.849
# 364     28.561     77.244
# 365     28.561     77.254
# 367     28.561     77.275
# 500     28.590     77.296
# 528     28.600     77.150
# 529     28.600     77.161
# 534     28.600     77.213
# 535     28.600     77.223
# 537     28.600     77.244
# 541     28.600     77.285
# 542     28.600     77.296
# 543     28.600     77.306
# 544     28.600     77.316
# 545     28.600     77.327
# 546     28.610     76.880
# 547     28.610     76.891
# 578     28.610     77.213
# 579     28.610     77.223
# 580     28.610     77.233
# 581     28.610     77.244
# 585     28.610     77.285
# 586     28.610     77.296
# ...

# %% [raw]
# import pandas as pd
# import numpy as np
# from pykrige.ok import OrdinaryKriging
#
# # Sample DataFrame with NaN values (replace with your actual data)
# data = {
#     'Latitude': [28.414, 28.414, 28.414, 28.414, 28.414],
#     'Longitude': [77.171, 77.181, 77.192, 77.202, 77.213],
#     '2018-01-01': [0.282, 0.287, 0.293, 0.298, 0.307],
#     '2018-01-02': [0.322, np.nan, 0.293, 0.305, 0.319],
#     '2018-01-03': [0.312, 0.314, 0.317, 0.323, 0.335],
#     '2018-01-04': [0.816, np.nan, 0.317, np.nan, 0.335],
#     # ... other columns ...
# }
#
# df = pd.DataFrame(data)
# df

# %%
# !pip install pykrige
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df.head()
# Out:
#    latitude  longitude  2018-01-01  2018-01-02  2018-01-03  2018-01-04  \
# 0    28.414     77.171       0.282       0.322       0.312       0.816
# 1    28.414     77.181       0.287       0.305       0.314         NaN
# 2    28.414     77.192       0.293       0.293       0.317         NaN
# 3    28.414     77.202       0.298       0.305       0.323         NaN
# 4    28.414     77.213       0.307       0.319       0.335         NaN
#
#    2018-01-05  2018-01-06  2018-01-07  2018-01-08  ...  2018-12-22  \
# 0         NaN       2.179       1.117       0.453  ...       0.552
# 1         NaN       2.154       1.069       0.455  ...       0.543
# 2         NaN       2.130       1.059       0.465  ...       0.550
# 3         NaN       2.129       1.047       0.480  ...       0.570
# 4         NaN       2.147       1.050       0.497  ...       0.591
#
#    2018-12-23  2018-12-24  2018-12-25  2018-12-26  2018-12-27  2018-12-28  \
# ...

# %%
# !pip install osmnx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd
import glob
from pykrige.ok import OrdinaryKriging
from pykrige.kriging_tools import write_asc_grid
import pykrige.kriging_tools as kt
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.patches import Path, PathPatch
#!pip install pykrige
import osmnx as ox
# %matplotlib inline
ox.config(log_console=True, use_cache=True)
# Out:
# /tmp/ipykernel_85503/1843521753.py:14: UserWarning:
#
# The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.

# %%
df1 = df[["latitude","longitude","2018-01-02"]]
df = pd.DataFrame(df1)

# Create a dataframe with only latitude and longitude where AOD values are NaN
nan_locations_df = df[df['2018-01-02'].isna()][['latitude', 'longitude']]

# Create a dataframe with latitude, longitude, and AOD values excluding NaN values
aod_df = df.dropna(subset=['2018-01-02'])[['latitude', 'longitude', '2018-01-02']]

# Print the dataframes
#print("Dataframe with NaN locations (Latitude and Longitude only):")
#print(nan_locations_df)
lons=np.array(aod_df['longitude'])
lats=np.array(aod_df['latitude'])
#lons
zdata=np.array(aod_df['2018-01-02'])
#zdata
OK = OrdinaryKriging(lons, lats, zdata, variogram_model='linear', verbose=True, enable_plotting=False,nlags=20)
grid_lon = np.array(nan_locations_df["longitude"])
grid_lat = np.array(nan_locations_df["latitude"])
z1, ss1 = OK.execute('grid', grid_lon, grid_lat)
nan_locations_df["2018-01-02"] = z1[0]
# Merge the two dataframes based on their indices
merged_df = pd.concat([aod_df, nan_locations_df], ignore_index=False)

# Print the merged dataframe
#print(merged_df)
# Sort the DataFrame by ascending index
merged_df = merged_df.sort_index(ascending=True)

# Display the sorted DataFrame
#print(merged_df)
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size (adjust as needed)
plt.figure(figsize=(10, 6))

# Create a heatmap of the "2018-01-02" column
# Pivot the DataFrame to create the heatmap data
heatmap_data = merged_df.pivot(index='latitude', columns='longitude', values='2018-01-02')
#sns.heatmap(heatmap_data, cmap='YlGnBu', annot=True, fmt=".3f")
contour = plt.contourf(heatmap_data.columns, heatmap_data.index, heatmap_data.values, cmap='viridis')
plt.colorbar(contour, label='AOD Value')

# Set axis labels and plot title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Heatmap of AOD Values (2018-01-02)')

# Show the heatmap
plt.show()
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.005628230857043947
# Nugget: 0.0017197627487383828
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...

# %%
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2018_sorted_dates.csv')
df.head()
# Out:
#    latitude  longitude  2018-01-01  2018-01-02  2018-01-03  2018-01-04  \
# 0    28.414     77.171       0.282       0.322       0.312       0.816
# 1    28.414     77.181       0.287       0.305       0.314         NaN
# 2    28.414     77.192       0.293       0.293       0.317         NaN
# 3    28.414     77.202       0.298       0.305       0.323         NaN
# 4    28.414     77.213       0.307       0.319       0.335         NaN
#
#    2018-01-05  2018-01-06  2018-01-07  2018-01-08  ...  2018-12-22  \
# 0         NaN       2.179       1.117       0.453  ...       0.552
# 1         NaN       2.154       1.069       0.455  ...       0.543
# 2         NaN       2.130       1.059       0.465  ...       0.550
# 3         NaN       2.129       1.047       0.480  ...       0.570
# 4         NaN       2.147       1.050       0.497  ...       0.591
#
#    2018-12-23  2018-12-24  2018-12-25  2018-12-26  2018-12-27  2018-12-28  \
# ...

# %%
import pandas as pd
from pykrige.ok import OrdinaryKriging
import numpy as np

def estimate_aod(df, date_column, nlags=20):
    # Create a DataFrame with only latitude, longitude, and the specified date column
    df1 = df[['latitude', 'longitude', date_column]]

    # Create a DataFrame with latitude and longitude where the specified date column's values are NaN
    nan_locations_df = df1[df1[date_column].isna()][['latitude', 'longitude']]

    # Create a DataFrame with latitude, longitude, and the specified date column excluding NaN values
    aod_df = df1.dropna(subset=[date_column])[['latitude', 'longitude', date_column]]

    # Prepare the data for Ordinary Kriging
    lons = np.array(aod_df['longitude'])
    lats = np.array(aod_df['latitude'])
    zdata = np.array(aod_df[date_column])

    # Perform Ordinary Kriging
    OK = OrdinaryKriging(lons, lats, zdata, variogram_model='linear', verbose=True, enable_plotting=False, nlags=nlags)
    grid_lon = np.array(nan_locations_df["longitude"])
    grid_lat = np.array(nan_locations_df["latitude"])
    z1, ss1 = OK.execute('grid', grid_lon, grid_lat)

    # Fill in NaN values in the specified date column with the interpolated values
    nan_locations_df[date_column] = z1[0]

    # Merge the two DataFrames based on their indices
    merged_df = pd.concat([aod_df, nan_locations_df], ignore_index=False)

    # Sort the DataFrame by ascending index
    merged_df = merged_df.sort_index(ascending=True)

    return merged_df

# Example usage:
# df = your_dataframe  # Replace 'your_dataframe' with your actual DataFrame
# date_column = '2018-01-02'  # Replace with the date column you want to estimate
# result_df = estimate_aod(df, date_column)

# Now 'result_df' contains the DataFrame with estimated AOD values for the specified date column.

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-01-02'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.005628230857043947
# Nugget: 0.0017197627487383828
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#       latitude  longitude  2018-01-02
# 0       28.414     77.171       0.322
# 1       28.414     77.181       0.305
# 2       28.414     77.192       0.293
# 3       28.414     77.202       0.305
# 4       28.414     77.213       0.319
# ...        ...        ...         ...
# 1345    28.864     77.078       0.235
# 1346    28.864     77.088       0.246
# 1347    28.864     77.098       0.248
# 1348    28.864     77.109       0.246
# 1349    28.874     77.088       0.241
#
# [1350 rows x 3 columns]

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-13'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 3
#       1 df = df  # Replace 'your_dataframe' with your actual DataFrame
#       2 date_column = '2018-11-13'  # Replace with the date column you want to estimate
# ----> 3 result_df = estimate_aod(df, date_column)
#       4 result_df
#
# Cell In[28], line 21, in estimate_aod(df, date_column, nlags)
#      18 zdata = np.array(aod_df[date_column])
#      20 # Perform Ordinary Kriging
# ---> 21 OK = OrdinaryKriging(lons, lats, zdata, variogram_model='linear', verbose=True, enable_plotting=False, nlags=nlags)
#      22 grid_lon = np.array(nan_locations_df["longitude"])
#      23 grid_lat = np.array(nan_locations_df["latitude"])
#
# ...

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-05'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 1.5237219682135848e-09
# Nugget: 0.029529448942877703
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#       latitude  longitude  2018-11-05
# 0       28.414     77.171    0.498849
# 1       28.414     77.181    0.498849
# 2       28.414     77.192    0.498849
# 3       28.414     77.202    0.498849
# 4       28.414     77.213    0.498849
# ...        ...        ...         ...
# 1345    28.864     77.078    0.498849
# 1346    28.864     77.088    0.498849
# 1347    28.864     77.098    0.498849
# 1348    28.864     77.109    0.498849
# 1349    28.874     77.088    0.498849
#
# [1350 rows x 3 columns]

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-07'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.014120417994346277
# Nugget: 0.0019301790481340507
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#       latitude  longitude  2018-11-07
# 0       28.414     77.171       0.779
# 1       28.414     77.181       0.737
# 2       28.414     77.192       0.736
# 3       28.414     77.202       0.755
# 4       28.414     77.213       0.780
# ...        ...        ...         ...
# 1345    28.864     77.078       0.854
# 1346    28.864     77.088       0.947
# 1347    28.864     77.098       0.930
# 1348    28.864     77.109       0.914
# 1349    28.874     77.088       0.837
#
# [1350 rows x 3 columns]

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-06'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.006894724510543839
# Nugget: 0.0022530137277430176
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#       latitude  longitude  2018-11-06
# 0       28.414     77.171       0.684
# 1       28.414     77.181       0.658
# 2       28.414     77.192       0.673
# 3       28.414     77.202       0.696
# 4       28.414     77.213       0.740
# ...        ...        ...         ...
# 1345    28.864     77.078       0.848
# 1346    28.864     77.088       0.805
# 1347    28.864     77.098       0.799
# 1348    28.864     77.109       0.786
# 1349    28.874     77.088       0.813
#
# [1350 rows x 3 columns]

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-09'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.004377738602259843
# Nugget: 0.0031896817541568765
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#       latitude  longitude  2018-11-09
# 0       28.414     77.171       0.937
# 1       28.414     77.181       0.880
# 2       28.414     77.192       0.890
# 3       28.414     77.202       0.880
# 4       28.414     77.213       0.892
# ...        ...        ...         ...
# 1345    28.864     77.078       0.939
# 1346    28.864     77.088       0.954
# 1347    28.864     77.098       0.949
# 1348    28.864     77.109       0.928
# 1349    28.874     77.088       0.866
#
# [1350 rows x 3 columns]

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-12'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.02873607215799546
# Nugget: 0.0017493076037081413
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#       latitude  longitude  2018-11-12
# 0       28.414     77.171    2.981000
# 1       28.414     77.181    2.972000
# 2       28.414     77.192    2.965000
# 3       28.414     77.202    2.963000
# 4       28.414     77.213    2.969000
# ...        ...        ...         ...
# 1345    28.864     77.078    3.004558
# 1346    28.864     77.088    3.203000
# 1347    28.864     77.098    3.210000
# 1348    28.864     77.109    3.203000
# 1349    28.874     77.088    3.012339
#
# [1350 rows x 3 columns]

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-11'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 df = df  # Replace 'your_dataframe' with your actual DataFrame
#       2 date_column = '2018-11-11'  # Replace with the date column you want to estimate
# ----> 3 result_df = estimate_aod(df, date_column)
#       4 result_df
#
# Cell In[28], line 21, in estimate_aod(df, date_column, nlags)
#      18 zdata = np.array(aod_df[date_column])
#      20 # Perform Ordinary Kriging
# ---> 21 OK = OrdinaryKriging(lons, lats, zdata, variogram_model='linear', verbose=True, enable_plotting=False, nlags=nlags)
#      22 grid_lon = np.array(nan_locations_df["longitude"])
#      23 grid_lat = np.array(nan_locations_df["latitude"])
#
# ...

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
date_column = '2018-11-10'  # Replace with the date column you want to estimate
result_df = estimate_aod(df, date_column)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.09432095182666034
# Nugget: 4.942661868867982e-11
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#       latitude  longitude  2018-11-10
# 0       28.414     77.171       1.439
# 1       28.414     77.181       1.448
# 2       28.414     77.192       1.452
# 3       28.414     77.202       1.473
# 4       28.414     77.213       1.501
# ...        ...        ...         ...
# 1345    28.864     77.078       1.542
# 1346    28.864     77.088       1.474
# 1347    28.864     77.098       1.476
# 1348    28.864     77.109       1.490
# 1349    28.874     77.088       1.548
#
# [1350 rows x 3 columns]

# %%
import pandas as pd
from pykrige.ok import OrdinaryKriging
import numpy as np

def estimate_aod(df, nlags=20):
    # Get the list of date columns with NaN values
    date_columns_with_nan = [col for col in df.columns[2:] if df[col].isna().any()]

    # Create an empty DataFrame to store the merged results
    merged_df = pd.DataFrame()

    # Iterate over the date columns with NaN values
    for date_column in date_columns_with_nan:
        # Create a DataFrame with only latitude, longitude, and the current date column
        df1 = df[['latitude', 'longitude', date_column]]

        # Create a DataFrame with latitude and longitude where the current date column's values are NaN
        nan_locations_df = df1[df1[date_column].isna()][['latitude', 'longitude']]

        # Create a DataFrame with latitude, longitude, and the current date column excluding NaN values
        aod_df = df1.dropna(subset=[date_column])[['latitude', 'longitude', date_column]]

        # Prepare the data for Ordinary Kriging
        lons = np.array(aod_df['longitude'])
        lats = np.array(aod_df['latitude'])
        zdata = np.array(aod_df[date_column])

        # Perform Ordinary Kriging
        OK = OrdinaryKriging(lons, lats, zdata, variogram_model='linear', verbose=True, enable_plotting=False, nlags=nlags)
        grid_lon = np.array(nan_locations_df["longitude"])
        grid_lat = np.array(nan_locations_df["latitude"])
        z1, ss1 = OK.execute('grid', grid_lon, grid_lat)

        # Fill in NaN values in the current date column with the interpolated values
        nan_locations_df[date_column] = z1[0]

        # Concatenate the dataframes
        aod_df = pd.concat([aod_df, nan_locations_df], ignore_index=False)

        # Sort the DataFrame by ascending index
        aod_df = aod_df.sort_index(ascending=True)

        # Concatenate the current date column's result with the merged DataFrame
        merged_df = pd.concat([merged_df, aod_df], axis=1)

    return merged_df

# Example usage:
# df = your_dataframe  # Replace 'your_dataframe' with your actual DataFrame
# result_df = estimate_aod(df)

# Now 'result_df' contains the DataFrame with estimated AOD values for all date columns with NaN values.

# %%
df = df  # Replace 'your_dataframe' with your actual DataFrame
#date_column = '2018-11-10'  # Replace with the date column you want to estimate
result_df = estimate_aod(df)
result_df
# Out:
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.005628230857095563
# Nugget: 0.0017197627487250573
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.004170486754411729
# Nugget: 0.0002544361446189428
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# Slope: 0.17068467306802204
# Nugget: 5.128199390940511e-13
#
# Calculating statistics on variogram model fit...
# Executing Ordinary Kriging...
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'linear' Variogram Model
# ...
