# %%
import pandas as pd

# %% [markdown]
# # 2018 year nan values distribution

# %%
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2018_sorted_dates .csv')
df.head()
# Out:
#    latitude  longitude  2018-01-01  2018-01-02  2018-01-03  2018-01-04  \
# 0    28.414     77.171         NaN       0.322         NaN       0.816
# 1    28.414     77.181         NaN       0.305         NaN         NaN
# 2    28.414     77.192         NaN       0.293         NaN         NaN
# 3    28.414     77.202         NaN       0.305         NaN         NaN
# 4    28.414     77.213         NaN       0.319         NaN         NaN
#
#    2018-01-05  2018-01-06  2018-01-07  2018-01-08  ...  2018-12-22  \
# 0       1.422       2.179       1.117         NaN  ...       0.552
# 1       1.360       2.154       1.069         NaN  ...       0.543
# 2       1.337       2.130       1.059         NaN  ...       0.550
# 3       1.314       2.129       1.047         NaN  ...       0.570
# 4       1.327       2.147       1.050         NaN  ...       0.591
#
#    2018-12-23  2018-12-24  2018-12-25  2018-12-26  2018-12-27  2018-12-28  \
# 0       0.933       1.650       0.921         NaN       0.554         NaN
# 1       0.936       1.620       0.884         NaN       0.522         NaN
# 2       0.954       1.626       0.870         NaN       0.516         NaN
# 3       0.973       1.654       0.863         NaN       0.533         NaN
# 4       1.009       1.703       0.879         NaN       0.579         NaN
#
#    2018-12-29  2018-12-30  2018-12-31
# 0       0.906         NaN         NaN
# 1       0.893         NaN       1.329
# 2       0.897         NaN       1.334
# 3       0.899         NaN       1.335
# 4       0.919         NaN       1.362
#
# [5 rows x 367 columns]

# %%
import pandas as pd
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2018_sorted_dates .csv')

def count_columns_with_null_in_intervals(dataframe):
    # Initialize counters for each interval
    interval_25_33 = 0
    interval_0_25 = 0
    interval_33_50 = 0
    interval_50_75 = 0
    interval_above_75 = 0
    
    # Iterate through all the columns except the first two
    for column_name in dataframe.columns[2:]:
        column_data = dataframe[column_name]
        
        # Calculate the total number of null values in the column
        total_null = column_data.isna().sum()
        
        # Calculate the percentage of null values in the column
        percentage_null = (total_null / len(column_data)) * 100
        
        # Check which interval the percentage falls into and update the corresponding counter
        if 25 <= percentage_null <= 33:
            interval_25_33 += 1
        elif 0 <= percentage_null < 25:
            interval_0_25 += 1
        elif 33 < percentage_null <= 50:
            interval_33_50 += 1
        elif 50 < percentage_null <= 75:
            interval_50_75 += 1
        else:
            interval_above_75 += 1
    
    return {
        '25-33%': interval_25_33,
        '0-25%': interval_0_25,
        '33-50%': interval_33_50,
        '50-75%': interval_50_75,
        'Above 75%': interval_above_75
    }


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
import matplotlib.pyplot as plt
# Create a pie plot
labels = interval_counts.keys()
sizes = interval_counts.values()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Columns with Null Values in Intervals in the year 2018')

# Display the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("/home/sysadm/Downloads/nan_values_2018.png")
plt.show()
# Out:
# Columns with null values in 25-33% interval: 11
# Columns with null values in 0-25% interval: 119
# Columns with null values in 33-50% interval: 21
# Columns with null values in 50-75% interval: 19
# Columns with null values in Above 75% interval: 195

# %%
import matplotlib.pyplot as plt
# Create a pie plot
labels = interval_counts.keys()
sizes = interval_counts.values()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Columns with Null Values in Intervals in the year 2018')

# Display the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("/home/sysadm/Downloads/nan_values_2018.png")
plt.show()

# %% [markdown]
# # 2019 year null value distribution

# %%
import pandas as pd
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2019_sorted_dates.csv')

def count_columns_with_null_in_intervals(dataframe):
    # Initialize counters for each interval
    interval_25_33 = 0
    interval_0_25 = 0
    interval_33_50 = 0
    interval_50_75 = 0
    interval_above_75 = 0
    
    # Iterate through all the columns except the first two
    for column_name in dataframe.columns[2:]:
        column_data = dataframe[column_name]
        
        # Calculate the total number of null values in the column
        total_null = column_data.isna().sum()
        
        # Calculate the percentage of null values in the column
        percentage_null = (total_null / len(column_data)) * 100
        
        # Check which interval the percentage falls into and update the corresponding counter
        if 25 <= percentage_null <= 33:
            interval_25_33 += 1
        elif 0 <= percentage_null < 25:
            interval_0_25 += 1
        elif 33 < percentage_null <= 50:
            interval_33_50 += 1
        elif 50 < percentage_null <= 75:
            interval_50_75 += 1
        else:
            interval_above_75 += 1
    
    return {
        '25-33%': interval_25_33,
        '0-25%': interval_0_25,
        '33-50%': interval_33_50,
        '50-75%': interval_50_75,
        'Above 75%': interval_above_75
    }


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
import matplotlib.pyplot as plt
# Create a pie plot
labels = interval_counts.keys()
sizes = interval_counts.values()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Columns with Null Values in Intervals in the year 2019')

# Display the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("/home/sysadm/Downloads/nan_values_2019.png")
plt.show()
# Out:
# Columns with null values in 25-33% interval: 10
# Columns with null values in 0-25% interval: 90
# Columns with null values in 33-50% interval: 13
# Columns with null values in 50-75% interval: 23
# Columns with null values in Above 75% interval: 229

# %% [markdown]
# # 2020 years nan values distribution

# %%
import pandas as pd
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2020_sorted_dates.csv')

def count_columns_with_null_in_intervals(dataframe):
    # Initialize counters for each interval
    interval_25_33 = 0
    interval_0_25 = 0
    interval_33_50 = 0
    interval_50_75 = 0
    interval_above_75 = 0
    
    # Iterate through all the columns except the first two
    for column_name in dataframe.columns[2:]:
        column_data = dataframe[column_name]
        
        # Calculate the total number of null values in the column
        total_null = column_data.isna().sum()
        
        # Calculate the percentage of null values in the column
        percentage_null = (total_null / len(column_data)) * 100
        
        # Check which interval the percentage falls into and update the corresponding counter
        if 25 <= percentage_null <= 33:
            interval_25_33 += 1
        elif 0 <= percentage_null < 25:
            interval_0_25 += 1
        elif 33 < percentage_null <= 50:
            interval_33_50 += 1
        elif 50 < percentage_null <= 75:
            interval_50_75 += 1
        else:
            interval_above_75 += 1
    
    return {
        '25-33%': interval_25_33,
        '0-25%': interval_0_25,
        '33-50%': interval_33_50,
        '50-75%': interval_50_75,
        'Above 75%': interval_above_75
    }


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
import matplotlib.pyplot as plt
# Create a pie plot
labels = interval_counts.keys()
sizes = interval_counts.values()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Columns with Null Values in Intervals in the year 2020')

# Display the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("/home/sysadm/Downloads/nan_values_2020.png")
plt.show()
# Out:
# Columns with null values in 25-33% interval: 8
# Columns with null values in 0-25% interval: 108
# Columns with null values in 33-50% interval: 24
# Columns with null values in 50-75% interval: 22
# Columns with null values in Above 75% interval: 204

# %%
import pandas as pd
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2021_sorted_dates.csv')

def count_columns_with_null_in_intervals(dataframe):
    # Initialize counters for each interval
    interval_25_33 = 0
    interval_0_25 = 0
    interval_33_50 = 0
    interval_50_75 = 0
    interval_above_75 = 0
    
    # Iterate through all the columns except the first two
    for column_name in dataframe.columns[2:]:
        column_data = dataframe[column_name]
        
        # Calculate the total number of null values in the column
        total_null = column_data.isna().sum()
        
        # Calculate the percentage of null values in the column
        percentage_null = (total_null / len(column_data)) * 100
        
        # Check which interval the percentage falls into and update the corresponding counter
        if 25 <= percentage_null <= 33:
            interval_25_33 += 1
        elif 0 <= percentage_null < 25:
            interval_0_25 += 1
        elif 33 < percentage_null <= 50:
            interval_33_50 += 1
        elif 50 < percentage_null <= 75:
            interval_50_75 += 1
        else:
            interval_above_75 += 1
    
    return {
        '25-33%': interval_25_33,
        '0-25%': interval_0_25,
        '33-50%': interval_33_50,
        '50-75%': interval_50_75,
        'Above 75%': interval_above_75
    }


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
import matplotlib.pyplot as plt
# Create a pie plot
labels = interval_counts.keys()
sizes = interval_counts.values()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Columns with Null Values in Intervals in the year 2021')

# Display the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("/home/sysadm/Downloads/nan_values_2021.png")
plt.show()
# Out:
# Columns with null values in 25-33% interval: 10
# Columns with null values in 0-25% interval: 94
# Columns with null values in 33-50% interval: 12
# Columns with null values in 50-75% interval: 23
# Columns with null values in Above 75% interval: 226

# %% [markdown]
# # 2022 year distribution

# %%
import pandas as pd
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2022_sorted_dates.csv')

def count_columns_with_null_in_intervals(dataframe):
    # Initialize counters for each interval
    interval_25_33 = 0
    interval_0_25 = 0
    interval_33_50 = 0
    interval_50_75 = 0
    interval_above_75 = 0
    
    # Iterate through all the columns except the first two
    for column_name in dataframe.columns[2:]:
        column_data = dataframe[column_name]
        
        # Calculate the total number of null values in the column
        total_null = column_data.isna().sum()
        
        # Calculate the percentage of null values in the column
        percentage_null = (total_null / len(column_data)) * 100
        
        # Check which interval the percentage falls into and update the corresponding counter
        if 25 <= percentage_null <= 33:
            interval_25_33 += 1
        elif 0 <= percentage_null < 25:
            interval_0_25 += 1
        elif 33 < percentage_null <= 50:
            interval_33_50 += 1
        elif 50 < percentage_null <= 75:
            interval_50_75 += 1
        else:
            interval_above_75 += 1
    
    return {
        '25-33%': interval_25_33,
        '0-25%': interval_0_25,
        '33-50%': interval_33_50,
        '50-75%': interval_50_75,
        'Above 75%': interval_above_75
    }


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
import matplotlib.pyplot as plt
# Create a pie plot
labels = interval_counts.keys()
sizes = interval_counts.values()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Columns with Null Values in Intervals in the year 2022')

# Display the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("/home/sysadm/Downloads/nan_values_2022.png")
plt.show()
# Out:
# Columns with null values in 25-33% interval: 9
# Columns with null values in 0-25% interval: 137
# Columns with null values in 33-50% interval: 10
# Columns with null values in 50-75% interval: 16
# Columns with null values in Above 75% interval: 193

# %% [markdown]
# # 2023 year nan values distribution

# %%
import pandas as pd
df = pd.read_csv('/home/sysadm/Downloads/merged_data_2023_sorted_dates.csv')

def count_columns_with_null_in_intervals(dataframe):
    # Initialize counters for each interval
    interval_25_33 = 0
    interval_0_25 = 0
    interval_33_50 = 0
    interval_50_75 = 0
    interval_above_75 = 0
    
    # Iterate through all the columns except the first two
    for column_name in dataframe.columns[2:]:
        column_data = dataframe[column_name]
        
        # Calculate the total number of null values in the column
        total_null = column_data.isna().sum()
        
        # Calculate the percentage of null values in the column
        percentage_null = (total_null / len(column_data)) * 100
        
        # Check which interval the percentage falls into and update the corresponding counter
        if 25 <= percentage_null <= 33:
            interval_25_33 += 1
        elif 0 <= percentage_null < 25:
            interval_0_25 += 1
        elif 33 < percentage_null <= 50:
            interval_33_50 += 1
        elif 50 < percentage_null <= 75:
            interval_50_75 += 1
        else:
            interval_above_75 += 1
    
    return {
        '25-33%': interval_25_33,
        '0-25%': interval_0_25,
        '33-50%': interval_33_50,
        '50-75%': interval_50_75,
        'Above 75%': interval_above_75
    }


# Get the count of columns with null values in specified intervals
interval_counts = count_columns_with_null_in_intervals(df)

# Print the counts for each interval
for key, value in interval_counts.items():
    print(f"Columns with null values in {key} interval: {value}")
import matplotlib.pyplot as plt
# Create a pie plot
labels = interval_counts.keys()
sizes = interval_counts.values()
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)

# Add a title
plt.title('Columns with Null Values in Intervals in the year 2023')

# Display the plot
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.savefig("/home/sysadm/Downloads/nan_values_2023.png")
plt.show()
# Out:
# Columns with null values in 25-33% interval: 9
# Columns with null values in 0-25% interval: 94
# Columns with null values in 33-50% interval: 18
# Columns with null values in 50-75% interval: 28
# Columns with null values in Above 75% interval: 220
